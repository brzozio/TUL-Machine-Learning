# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

# Define the confusion matrix
conf_matrix = np.array([[ 255,  104,   98,   69,   33,   12]
                        [  58,  248  316  326  123   26]
                        [  20  138  817  730  260   39]
                        [  22   63  380 1487  728   97]
                        [  12   35  223  908 1011  155]
                        [  11   24  151  537  645  579]])

# Define the class labels
classes = ['0', '1', '2', '3', '4', '5']

# Plot the confusion matrix using seaborn heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.title('kNN')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Define the new confusion matrix
conf_matrix = np.array([[ 255,  104,   98,   69,   33,   12],
                        [  58,  248,  316,  326,  123,   26],
                        [  20,  138,  817,  730,  260,   39],
                        [  22,   63,  380, 1487,  728,   97],
                        [  12,   35,  223,  908, 1011,  155],
                        [  11,   24,  151,  537,  645,  579]])

# Define the class labels
classes = ['0', '1', '2', '3', '4', '5']

# Plot the confusion matrix using seaborn heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.title('Collaborative filtering')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Define the updated confusion matrix
conf_matrix = np.array([[  85,  102,  189,  146,   38,   11],
                        [  17,   79,  319,  517,  146,   19],
                        [  11,   56,  671,  918,  319,   29],
                        [  10,   60,  336, 1636,  674,   61],
                        [  10,   41,  273, 1155,  795,   70],
                        [  18,   38,  213,  694,  742,  242]])

# Define the class labels
classes = ['0', '1', '2', '3', '4', '5']

# Plot the confusion matrix using seaborn heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.title('Decision Tree')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Define the confusion matrix for Random Forest
conf_matrix = np.array([[  39,  108,  231,  173,   19,    1],
                        [   2,   62,  272,  665,   93,    3],
                        [   0,   29,  613, 1125,  227,   10],
                        [   1,   30,  239, 1923,  568,   16],
                        [   2,   24,  159, 1425,  722,   12],
                        [   4,   19,  144,  821,  772,  187]])

# Define the class labels
classes = ['0', '1', '2', '3', '4', '5']

# Plot the confusion matrix using seaborn heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.title('Random Forest')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Define the confusion matrix for Person Similarity
conf_matrix = np.array([[ 321,   47,   82,   48,   38,   35],
                        [  25,  421,  218,  239,  133,   61],
                        [  20,   51, 1099,  480,  243,  111],
                        [  21,   60,  273, 1684,  556,  183],
                        [  12,   38,  157,  726, 1269,  142],
                        [  21,   40,  149,  469,  388,  880]])

# Define the class labels
classes = ['0', '1', '2', '3', '4', '5']

# Plot the confusion matrix using seaborn heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.title('Person Similarity')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
